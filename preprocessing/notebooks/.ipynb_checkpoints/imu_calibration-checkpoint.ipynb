# %%
import numpy as np
import sys
sys.path.insert(1,'/home/zhanibek/.local/lib/python2.7/site-packages/cv2')
sys.path.insert(1,'/home/zhanibek/catkin_ws/src/smart_tray/scripts/')
import cv2 
import matplotlib.pyplot as plt
import os
from tqdm import tqdm_notebook
import pickle
import pandas as pd
from phri.utils import *
import scipy.io as sio


import plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets

# %%
calib_data_path = '/home/zhanibek/codes/phhi_data_analysis/data/imu_calibration_2020-11-02-14-58-29.pkl'

# %%
data_df = pickle.load(open(calib_data_path))

# %%
imu_df = data_df['/imu_data']
imu_df.head()
# Out:
#      seq    time_stamp                 frame_id  \
# 0  14181  1.602502e+09  LSM9DS1_IMU_SENSOR_DATA
# 1  14182  1.602502e+09  LSM9DS1_IMU_SENSOR_DATA
# 2  14183  1.602502e+09  LSM9DS1_IMU_SENSOR_DATA
# 3  14184  1.602502e+09  LSM9DS1_IMU_SENSOR_DATA
# 4  14185  1.602502e+09  LSM9DS1_IMU_SENSOR_DATA
#
#                                                accel  \
# 0  [0.2913855590820313, -0.1818916015625, 10.9021...
# 1  [0.2722390747070313, -0.2165946044921875, 10.9...
# 2  [0.2877955932617188, -0.23633941650390627, 10....
# 3  [0.289590576171875, -0.22796282958984376, 11.0...
# 4  [0.3189086303710938, -0.21001300048828125, 10....
#
#                                                 gyro  \
# 0  [3.701019287109375, -7.394561767578125, -1.652...
# 1  [3.7982177734375, -6.975860595703125, -1.71966...
# 2  [3.70849609375, -7.484283447265625, -1.8318176...
# 3  [4.104766845703125, -7.185211181640625, -1.899...
# 4  [3.686065673828125, -7.170257568359375, -1.891...
#
#                                                  mag
# 0  [0.02687999978661537, 0.326200008392334, -0.33...
# 1  [0.024640001356601715, 0.32396000623703003, -0...
# 2  [0.02240000106394291, 0.3241000175476074, -0.3...
# 3  [0.025200000032782555, 0.32269999384880066, -0...
# 4  [0.027580000460147858, 0.32396000623703003, -0...

# %%
data_df.keys()
# Out:
# ['/imu_data', 'summary']

# %%
data_df['summary']
# Out:
#   topic_name  message_count  frequency            msg_type    start_time  \
# 0  /imu_data           7489  77.362131  smart_tray/imu_msg  1.604351e+09
#
#        end_time
# 0  1.604351e+09

# %%
t = imu_df['time_stamp'].to_numpy()

accel = imu_df['accel'].to_numpy()
accel = np.array([[f[0],f[1],f[2]] for f in accel])

mag = imu_df['mag'].to_numpy()
mag = np.array([[f[0],f[1],f[2]] for f in mag])

gyro = imu_df['gyro'].to_numpy()
gyro = np.array([[f[0],f[1],f[2]] for f in gyro])

# %% [markdown]
# ### Export to .mat file

# %%
sio.savemat('/home/zhanibek/codes/phhi_data_analysis/data/magnetometer_calib.mat',
            {'t':t,'mag':mag, 'accel':accel, 'gyro':gyro})

# %%
plt.plot(mag[:,0], mag[:,1],'.')
plt.grid()

# %%
plt.plot(mag[:,0], mag[:,2],'.')
plt.grid()

# %%
plt.plot(mag[:,1], mag[:,2],'.')
plt.grid()

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.plot(mag[:,0],mag[:,1],mag[:,2],'o', MarkerSize=1)

# %%
A = 
    0.9249    0.0957   -0.0063
    0.0957    1.0708   -0.0565
   -0.0063   -0.0565    1.0221

b =

    0.0377    0.1454   -0.0653

expmfs =

    0.4166
